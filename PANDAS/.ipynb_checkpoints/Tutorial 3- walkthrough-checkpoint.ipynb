# %%
# %matplotlib inline
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We are going to import the data a little differently this time. I have created a data set that adds the day of the week run as a column. To import this without having to rename columns we are going to parse the data for datetime and grab the column names all at once as shown below

# %%
list(range(1,9))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
df= pd.read_csv('../PANDAS/data/DataForTutorial3.csv', parse_dates=['Date'], usecols=list(range(1,8)))

# %%
df.head()
# Out:
#         Date  Miles Time  Seconds  Minutes  Minutes_per_Mile Day_of_week
# 0 2014-08-01    0.0  NaN      NaN      NaN               NaN      Friday
# 1 2014-08-02    1.7  NaN      NaN      NaN               NaN    Saturday
# 2 2014-08-03    1.4  NaN      NaN      NaN               NaN      Sunday
# 3 2014-08-04    2.1  NaN      NaN      NaN               NaN      Monday
# 4 2014-08-05    0.0  NaN      NaN      NaN               NaN     Tuesday

# %% [markdown]
#  We can now plot, using a bar plot, which day he runs most frequently

# %%
df.Day_of_week.value_counts().plot(kind='bar')

# %% [markdown]
# They all look rather similar when in reality there are more days missed than shown above. Let's plot this again but exclude any days when 'Miles' is a NaN value

# %%
df[df.Miles > 0].Day_of_week.value_counts().plot(kind='bar')

# %% [markdown]
# A little more realistic looking. Before diving in further let's delete some of the extraneous columns that we've added in that are no longer needed.
#
# Let's delete the 'Time' column and use the .pop command to remove the 'seconds' column from the DataFrame.

# %%
del(df['Time'])
df.head()
# Out:
#         Date  Miles  Seconds  Minutes  Minutes_per_Mile Day_of_week
# 0 2014-08-01    0.0      NaN      NaN               NaN      Friday
# 1 2014-08-02    1.7      NaN      NaN               NaN    Saturday
# 2 2014-08-03    1.4      NaN      NaN               NaN      Sunday
# 3 2014-08-04    2.1      NaN      NaN               NaN      Monday
# 4 2014-08-05    0.0      NaN      NaN               NaN     Tuesday

# %%
df.pop('Seconds')
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9       1717.0
# 10       787.0
# 11       635.0
# 12      1045.0
# 13       376.0
# 14       376.0
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21       573.0
# 22       564.0
# 23       545.0
# 24         NaN
# 25         NaN
# 26       535.0
# 27         NaN
# 28       630.0
# 29      1500.0
#         ...
# 138        NaN
# 139        NaN
# 140        NaN
# 141        NaN
# 142     1500.0
# 143        NaN
# 144        NaN
# 145      555.0
# 146     2616.0
# 147     1139.0
# 148        NaN
# 149     3523.0
# 150        NaN
# 151     5940.0
# 152        NaN
# 153     1575.0
# 154     8100.0
# 155        NaN
# 156     1680.0
# 157     3110.0
# 158     1508.0
# 159     8400.0
# 160        NaN
# 161        NaN
# 162        NaN
# 163        NaN
# 164     1330.0
# 165        NaN
# 166    15643.0
# 167        NaN
# Name: Seconds, Length: 168, dtype: float64

# %%
df.head()
# Out:
#         Date  Miles  Minutes  Minutes_per_Mile Day_of_week
# 0 2014-08-01    0.0      NaN               NaN      Friday
# 1 2014-08-02    1.7      NaN               NaN    Saturday
# 2 2014-08-03    1.4      NaN               NaN      Sunday
# 3 2014-08-04    2.1      NaN               NaN      Monday
# 4 2014-08-05    0.0      NaN               NaN     Tuesday

# %% [markdown]
# Well done. Pandas true strength comes in how it groups things. We are going to show this in this dataset by examining the data on a week by week basis
#
# First, remove all instances of Miles > 0 in the 'Miles' column

# %%
df['Miles'] = df.Miles[df.Miles > 0] 
df.head(10)
# Out:
#         Date  Miles    Minutes  Minutes_per_Mile Day_of_week
# 0 2014-08-01    NaN        NaN               NaN      Friday
# 1 2014-08-02   1.70        NaN               NaN    Saturday
# 2 2014-08-03   1.40        NaN               NaN      Sunday
# 3 2014-08-04   2.10        NaN               NaN      Monday
# 4 2014-08-05    NaN        NaN               NaN     Tuesday
# 5 2014-08-06   2.38        NaN               NaN   Wednesday
# 6 2014-08-07   2.30        NaN               NaN    Thursday
# 7 2014-08-08   3.40        NaN               NaN      Friday
# 8 2014-08-09   2.50        NaN               NaN    Saturday
# 9 2014-08-10   3.36  28.616667          8.516865      Sunday

# %% [markdown]
# Now we are going to use the groupby function to sort by day of week, print the .size of the function when you are ready which should tell you how many times he ran per each day. Another good statistical analysis is the .count which will break down the relationships of the other columns to the day of week

# %%
dayofweek = df.groupby('Day_of_week')
print(dayofweek)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x1167e8940>

# %%
dayofweek.size()
# Out:
# Day_of_week
# Friday       25
# Monday       25
# Saturday     27
# Sunday       23
# Thursday     23
# Tuesday      23
# Wednesday    22
# dtype: int64

# %%
dayofweek.count()
# Out:
#              Date  Miles  Minutes  Minutes_per_Mile
# Day_of_week
# Friday         25     15        8                 8
# Monday         25     14       10                10
# Saturday       27     14        6                 6
# Sunday         23     11        8                 8
# Thursday       23      8        5                 5
# Tuesday        23     11        8                 8
# Wednesday      22      8        7                 7

# %% [markdown]
# You can really use any of the common functions in analyzing grouping data, such as .sum, .describe, and .mean
#
# Try calling all of the data for the group 'Tuesday'

# %%
dayofweek.get_group('Tuesday')
# Out:
#           Date  Miles    Minutes  Minutes_per_Mile Day_of_week
# 4   2014-08-05    NaN        NaN               NaN     Tuesday
# 11  2014-08-12   1.42  10.583333          7.453052     Tuesday
# 19  2014-08-19   1.37        NaN               NaN     Tuesday
# 20  2014-08-19   1.37        NaN               NaN     Tuesday
# 28  2014-08-26   1.37  10.500000          7.664234     Tuesday
# 35  2014-09-02   2.00        NaN               NaN     Tuesday
# 42  2014-09-09    NaN        NaN               NaN     Tuesday
# 49  2014-09-16   3.05  22.800000          7.475410     Tuesday
# 56  2014-09-23    NaN        NaN               NaN     Tuesday
# 64  2014-09-30    NaN        NaN               NaN     Tuesday
# 73  2014-10-07    NaN        NaN               NaN     Tuesday
# 80  2014-10-14   1.37   9.083333          6.630170     Tuesday
# 89  2014-10-21    NaN        NaN               NaN     Tuesday
# 96  2014-10-28    NaN        NaN               NaN     Tuesday
# 103 2014-11-04   3.05  22.200000          7.278689     Tuesday
# 114 2014-11-11    NaN        NaN               NaN     Tuesday
# 121 2014-11-18    NaN        NaN               NaN     Tuesday
# 128 2014-11-25    NaN        NaN               NaN     Tuesday
# 135 2014-12-02    NaN        NaN               NaN     Tuesday
# 142 2014-12-09   2.93  25.000000          8.532423     Tuesday
# 150 2014-12-16    NaN        NaN               NaN     Tuesday
# 157 2014-12-23   5.63  51.833333          9.206631     Tuesday
# 164 2014-12-30   3.15  22.166667          7.037037     Tuesday

# %% [markdown]
# We can also organize all of the data by the day of the week using a two variable for loop go ahead and try it out

# %%
for name, group in dayofweek:
    print(name)
    print(group)
# Out:
# Friday
#           Date  Miles    Minutes  Minutes_per_Mile Day_of_week
# 0   2014-08-01    NaN        NaN               NaN      Friday
# 7   2014-08-08   3.40        NaN               NaN      Friday
# 15  2014-08-15   1.78        NaN               NaN      Friday
# 23  2014-08-22   1.37   9.083333          6.630170      Friday
# 31  2014-08-29   5.00  43.450000          8.690000      Friday
# 38  2014-09-05   3.05  23.833333          7.814208      Friday
# 45  2014-09-12   3.05  23.766667          7.792350      Friday
# 52  2014-09-19   1.37   9.750000          7.116788      Friday
# 59  2014-09-26    NaN        NaN               NaN      Friday
# 67  2014-10-03    NaN        NaN               NaN      Friday
# 76  2014-10-10    NaN        NaN               NaN      Friday
# 83  2014-10-17    NaN        NaN               NaN      Friday
# 92  2014-10-24    NaN        NaN               NaN      Friday
# 99  2014-10-31   2.01        NaN               NaN      Friday
# 106 2014-11-07   5.63  49.083333          8.718176      Friday
# 107 2014-11-07   1.26        NaN               NaN      Friday
# 108 2014-11-07   1.20        NaN               NaN      Friday
# 117 2014-11-14    NaN        NaN               NaN      Friday
# 124 2014-11-21    NaN        NaN               NaN      Friday
# 131 2014-11-28   3.00        NaN               NaN      Friday
# 138 2014-12-05    NaN        NaN               NaN      Friday
# 145 2014-12-12   1.37   9.250000          6.751825      Friday
# 153 2014-12-19   3.10  26.250000          8.467742      Friday
# 160 2014-12-26   5.20        NaN               NaN      Friday
# 167 2015-01-02    NaN        NaN               NaN      Friday
# Monday
#           Date  Miles    Minutes  Minutes_per_Mile Day_of_week
# 3   2014-08-04   2.10        NaN               NaN      Monday
# 10  2014-08-11   1.67  13.116667          7.854291      Monday
# 18  2014-08-18   0.65        NaN               NaN      Monday
# 26  2014-08-25   1.37   8.916667          6.508516      Monday
# 27  2014-08-25   1.34        NaN               NaN      Monday
# 34  2014-09-01    NaN        NaN               NaN      Monday
# 41  2014-09-08   3.05  23.183333          7.601093      Monday
# 48  2014-09-15    NaN        NaN               NaN      Monday
# 55  2014-09-22    NaN        NaN               NaN      Monday
# 63  2014-09-29   3.05  21.916667          7.185792      Monday
# 72  2014-10-06    NaN        NaN               NaN      Monday
# 79  2014-10-13    NaN        NaN               NaN      Monday
# 88  2014-10-20   1.37   8.600000          6.277372      Monday
# 95  2014-10-27    NaN        NaN               NaN      Monday
# 102 2014-11-03   5.30  39.433333          7.440252      Monday
# 111 2014-11-10   1.50   9.000000          6.000000      Monday
# 112 2014-11-10   1.50  11.550000          7.700000      Monday
# 113 2014-11-10   4.00        NaN               NaN      Monday
# 120 2014-11-17    NaN        NaN               NaN      Monday
# 127 2014-11-24    NaN        NaN               NaN      Monday
# 134 2014-12-01    NaN        NaN               NaN      Monday
# 141 2014-12-08    NaN        NaN               NaN      Monday
# 149 2014-12-15   6.50  58.716667          9.033333      Monday
# 156 2014-12-22   3.10  28.000000          9.032258      Monday
# 163 2014-12-29    NaN        NaN               NaN      Monday
# Saturday
#           Date  Miles     Minutes  Minutes_per_Mile Day_of_week
# 1   2014-08-02   1.70         NaN               NaN    Saturday
# 8   2014-08-09   2.50         NaN               NaN    Saturday
# 16  2014-08-16   0.65         NaN               NaN    Saturday
# 24  2014-08-23   1.34         NaN               NaN    Saturday
# 32  2014-08-30    NaN         NaN               NaN    Saturday
# 39  2014-09-06    NaN         NaN               NaN    Saturday
# 46  2014-09-13    NaN         NaN               NaN    Saturday
# 53  2014-09-20    NaN         NaN               NaN    Saturday
# 60  2014-09-27    NaN         NaN               NaN    Saturday
# 68  2014-10-04   4.63   40.000000          8.639309    Saturday
# 69  2014-10-04   1.87         NaN               NaN    Saturday
# 70  2014-10-04   4.08   33.000000          8.088235    Saturday
# 77  2014-10-11    NaN         NaN               NaN    Saturday
# 84  2014-10-18   1.50    9.666667          6.444444    Saturday
# 85  2014-10-18   1.50         NaN               NaN    Saturday
# 86  2014-10-18   1.37         NaN               NaN    Saturday
# 93  2014-10-25   2.00         NaN               NaN    Saturday
# 100 2014-11-01    NaN         NaN               NaN    Saturday
# 109 2014-11-08    NaN         NaN               NaN    Saturday
# 118 2014-11-15    NaN         NaN               NaN    Saturday
# 125 2014-11-22    NaN         NaN               NaN    Saturday
# 132 2014-11-29    NaN         NaN               NaN    Saturday
# 139 2014-12-06    NaN         NaN               NaN    Saturday
# 146 2014-12-13   5.30   43.600000          8.226415    Saturday
# 147 2014-12-13   2.21   18.983333          8.589744    Saturday
# 154 2014-12-20  14.80  135.000000          9.121622    Saturday
# 161 2014-12-27    NaN         NaN               NaN    Saturday
# Sunday
#           Date  Miles    Minutes  Minutes_per_Mile Day_of_week
# 2   2014-08-03   1.40        NaN               NaN      Sunday
# 9   2014-08-10   3.36  28.616667          8.516865      Sunday
# 17  2014-08-17   1.34        NaN               NaN      Sunday
# 25  2014-08-24   3.00        NaN               NaN      Sunday
# 33  2014-08-31    NaN        NaN               NaN      Sunday
# 40  2014-09-07    NaN        NaN               NaN      Sunday
# 47  2014-09-14    NaN        NaN               NaN      Sunday
# 54  2014-09-21   4.03  30.366667          7.535153      Sunday
# 61  2014-09-28   1.50  11.300000          7.533333      Sunday
# 62  2014-09-28   1.50  11.300000          7.533333      Sunday
# 71  2014-10-05    NaN        NaN               NaN      Sunday
# 78  2014-10-12   3.05  22.616667          7.415301      Sunday
# 87  2014-10-19    NaN        NaN               NaN      Sunday
# 94  2014-10-26    NaN        NaN               NaN      Sunday
# 101 2014-11-02   1.37   8.716667          6.362530      Sunday
# 110 2014-11-09   3.05  22.600000          7.409836      Sunday
# 119 2014-11-16    NaN        NaN               NaN      Sunday
# 126 2014-11-23   3.05  22.583333          7.404372      Sunday
# 133 2014-11-30    NaN        NaN               NaN      Sunday
# 140 2014-12-07    NaN        NaN               NaN      Sunday
# 148 2014-12-14    NaN        NaN               NaN      Sunday
# 155 2014-12-21    NaN        NaN               NaN      Sunday
# 162 2014-12-28    NaN        NaN               NaN      Sunday
# Thursday
#           Date  Miles     Minutes  Minutes_per_Mile Day_of_week
# 6   2014-08-07   2.30         NaN               NaN    Thursday
# 13  2014-08-14   0.90    6.266667          6.962963    Thursday
# 14  2014-08-14   0.90    6.266667          6.962963    Thursday
# 22  2014-08-21   1.37    9.400000          6.861314    Thursday
# 30  2014-08-28    NaN         NaN               NaN    Thursday
# 37  2014-09-04   3.05         NaN               NaN    Thursday
# 44  2014-09-11    NaN         NaN               NaN    Thursday
# 51  2014-09-18    NaN         NaN               NaN    Thursday
# 58  2014-09-25    NaN         NaN               NaN    Thursday
# 66  2014-10-02    NaN         NaN               NaN    Thursday
# 75  2014-10-09    NaN         NaN               NaN    Thursday
# 82  2014-10-16    NaN         NaN               NaN    Thursday
# 91  2014-10-23    NaN         NaN               NaN    Thursday
# 98  2014-10-30    NaN         NaN               NaN    Thursday
# 105 2014-11-06    NaN         NaN               NaN    Thursday
# 116 2014-11-13    NaN         NaN               NaN    Thursday
# 123 2014-11-20    NaN         NaN               NaN    Thursday
# 130 2014-11-27   1.00         NaN               NaN    Thursday
# 137 2014-12-04    NaN         NaN               NaN    Thursday
# 144 2014-12-11    NaN         NaN               NaN    Thursday
# 152 2014-12-18    NaN         NaN               NaN    Thursday
# 159 2014-12-25  14.80  140.000000          9.459459    Thursday
# 166 2015-01-01  26.20  260.716667          9.951018    Thursday
# Tuesday
#           Date  Miles    Minutes  Minutes_per_Mile Day_of_week
# 4   2014-08-05    NaN        NaN               NaN     Tuesday
# 11  2014-08-12   1.42  10.583333          7.453052     Tuesday
# 19  2014-08-19   1.37        NaN               NaN     Tuesday
# 20  2014-08-19   1.37        NaN               NaN     Tuesday
# 28  2014-08-26   1.37  10.500000          7.664234     Tuesday
# 35  2014-09-02   2.00        NaN               NaN     Tuesday
# 42  2014-09-09    NaN        NaN               NaN     Tuesday
# 49  2014-09-16   3.05  22.800000          7.475410     Tuesday
# 56  2014-09-23    NaN        NaN               NaN     Tuesday
# 64  2014-09-30    NaN        NaN               NaN     Tuesday
# 73  2014-10-07    NaN        NaN               NaN     Tuesday
# 80  2014-10-14   1.37   9.083333          6.630170     Tuesday
# 89  2014-10-21    NaN        NaN               NaN     Tuesday
# 96  2014-10-28    NaN        NaN               NaN     Tuesday
# 103 2014-11-04   3.05  22.200000          7.278689     Tuesday
# 114 2014-11-11    NaN        NaN               NaN     Tuesday
# 121 2014-11-18    NaN        NaN               NaN     Tuesday
# 128 2014-11-25    NaN        NaN               NaN     Tuesday
# 135 2014-12-02    NaN        NaN               NaN     Tuesday
# 142 2014-12-09   2.93  25.000000          8.532423     Tuesday
# 150 2014-12-16    NaN        NaN               NaN     Tuesday
# 157 2014-12-23   5.63  51.833333          9.206631     Tuesday
# 164 2014-12-30   3.15  22.166667          7.037037     Tuesday
# Wednesday
#           Date  Miles    Minutes  Minutes_per_Mile Day_of_week
# 5   2014-08-06   2.38        NaN               NaN   Wednesday
# 12  2014-08-13   2.35  17.416667          7.411348   Wednesday
# 21  2014-08-20   1.37   9.550000          6.970803   Wednesday
# 29  2014-08-27   2.50  25.000000         10.000000   Wednesday
# 36  2014-09-03    NaN        NaN               NaN   Wednesday
# 43  2014-09-10   1.37   8.950000          6.532847   Wednesday
# 50  2014-09-17   1.50  11.100000          7.400000   Wednesday
# 57  2014-09-24    NaN        NaN               NaN   Wednesday
# 65  2014-10-01    NaN        NaN               NaN   Wednesday
# 74  2014-10-08    NaN        NaN               NaN   Wednesday
# 81  2014-10-15    NaN        NaN               NaN   Wednesday
# 90  2014-10-22    NaN        NaN               NaN   Wednesday
# 97  2014-10-29    NaN        NaN               NaN   Wednesday
# 104 2014-11-05    NaN        NaN               NaN   Wednesday
# 115 2014-11-12    NaN        NaN               NaN   Wednesday
# 122 2014-11-19    NaN        NaN               NaN   Wednesday
# 129 2014-11-26    NaN        NaN               NaN   Wednesday
# 136 2014-12-03    NaN        NaN               NaN   Wednesday
# 143 2014-12-10    NaN        NaN               NaN   Wednesday
# 151 2014-12-17  12.00  99.000000          8.250000   Wednesday
# 158 2014-12-24   3.05  25.133333          8.240437   Wednesday
# 165 2014-12-31    NaN        NaN               NaN   Wednesday

# %% [markdown]
# One of the big takeaways from this section is how powerful the grouping function is in PANDAS. The grouping method allows us to create manageable chunks of data, analysis them and then merge those pieces back with the whole DataFrame seamlessly. While the dataset we worked on was fairly small one can imagine the uses for this method.
