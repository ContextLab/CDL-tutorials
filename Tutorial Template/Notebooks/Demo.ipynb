# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x= np.fromfile ('../Data/chirp.npy', dtype= float)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp')
plt.show()
# Out:
# /Users/Emily/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in square
