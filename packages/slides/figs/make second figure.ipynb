# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.arange(0, 4*np.pi, 1.0/1000.0)
y = np.sin(x)

# %%
plt.plot(x, y, 'k')
fig = plt.gcf()

# %%
fig.savefig('2sin.pdf')
