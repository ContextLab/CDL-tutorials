# %% [markdown]
# Importing all dependences

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# loading in saved data from the data folder
#
# plotting saved data with np.sin(x**2) being the y variable
#
# Titled the plot and used .show() to show it

# %%
x= np.load('../data/chirp.npy')
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp')
plt.show()
